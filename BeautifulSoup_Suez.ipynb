# %% [markdown]
# <a href="https://colab.research.google.com/github/ibwi/ibwi/blob/main/BeautifulSoup_Suez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# chargement des librairies utiles

from bs4 import BeautifulSoup
import requests
import csv

import urllib.request
import urllib.error
import bs4

import re

import pandas as pd

# %% [markdown]
# ### Partie 1 : récupération des URLs

# %%
rurl=requests.get('https://www.unea.fr/annuaire-des-entreprises-adaptees?sector=0&section=0&activity=0&keyword=&region=&lat=&lng=&autocomplete_selected=&form_build_id=form-qYY-_LbpYQE7EtvYA_TQaQlyQ0uNpAuJL0xts0cvpmg&form_id=ecedi_list_filter_form').text

# %%
soupurl = BeautifulSoup(rurl)

# %%
print(soupurl.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IEMobile 7]><html class="iem7"  lang="fr" dir="ltr"><![endif]-->
# <!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="fr" dir="ltr"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="fr" dir="ltr"><![endif]-->
# <!--[if IE 8]><html class="lt-ie9"  lang="fr" dir="ltr"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><!-->
# <html dir="ltr" lang="fr" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.unea.fr/sites/all/themes/custom/customer/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <meta content="La vitrine des Entreprises Adaptées Une mise à jour régulière de l'ensemble des informations" name="description"/>
#   <meta content="Drupal 7 (http://drupal.org)" name="generator"/>
#   <link href="https://www.unea.fr/annuaire-des-entreprises-adaptees" rel="canonical"/>
#   <link href="https://www.unea.fr/node/22" rel="shortlink"/>
#   <title>
#    Annuaire des Entreprises Adaptées | UNEA - Union Nationale des Entreprises Adaptées
#   </title>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="on" http-equiv="cleartype"/>
#   <style>
#    @import url("https://www.unea.fr/modules/system/system.base.css?qfc2p3");
#   </style>
#   <style>
#    @import url("https://www.unea.fr/sites/all/libraries/chosen/chosen.css?qfc2p3");
# @import url("https://www.unea.fr/sites/all/modules/contrib/chosen/css/chosen-drupal.css?qfc2p3");
#   </style>
#   <style>
#    @import url("https://www.unea.fr/sites/all/modules/contrib/date/date_api/date.css?qfc2p3");
# @import url("https://www.unea.fr/modules/field/theme/field.css?qfc2p3");
# @import url("https://www.unea.fr/modules/node/node.css?qfc2p3");
# @import url("https://www.unea.fr/modules/search/search.css?qfc2p3");
# @import url("https://www.unea.fr/modules/user/user.css?qfc2p3");
# @import url("https://www.unea.fr/sites/all/modules/contrib/views/css/views.css?qfc2p3");
#   </style>
#   <style>
#    @import url("https://www.unea.fr/sites/all/modules/contrib/ctools/css/ctools.css?qfc2p3");
# @import url("https://www.unea.fr/sites/all/libraries/fancybox/source/jquery.fancybox.css?qfc2p3");
# @import url("https://www.unea.fr/sites/all/modules/custom/prehome/css/prehome.css?qfc2p3");
# @import url("https://www.unea.fr/sites/all/modules/contrib/eu_cookie_compliance/css/eu_cookie_compliance.css?qfc2p3");
# @import url("https://www.unea.fr/sites/all/modules/contrib/search_api_autocomplete/search_api_autocomplete.css?qfc2p3");
#   </style>
#   <style>
#    #sliding-popup.sliding-popup-bottom,#sliding-popup.sliding-popup-bottom .eu-cookie-withdraw-banner,.eu-cookie-withdraw-tab{background:#0779BF;}#sliding-popup.sliding-popup-bottom.eu-cookie-withdraw-wrapper{background:transparent}#sliding-popup .popup-content #popup-text h1,#sliding-popup .popup-content #popup-text h2,#sliding-popup .popup-content #popup-text h3,#sliding-popup .popup-content #popup-text p,.eu-cookie-compliance-more-button,.eu-cookie-compliance-secondary-button,.eu-cookie-withdraw-tab{color:#ffffff !important;}.eu-cookie-withdraw-tab{border-color:#ffffff;}
#   </style>
#   <style>
#    @import url("https://www.unea.fr/sites/all/themes/custom/ecedi/css/ecedi.css?qfc2p3");
# @import url("https://www.unea.fr/sites/all/themes/custom/customer/../../../libraries/mCustomScrollbar/jquery.mCustomScrollbar.css?qfc2p3");
# @import url("https://www.unea.fr/sites/all/themes/custom/customer/css/styles_customer.css?qfc2p3");
#   </style>
#   <script src="https://www.unea.fr/sites/default/files/js/js_vIYJMoKYoMWkVusn3iML8i0Lt7Is3CRaFcqWuXJaFrM.js">
#   </script>
#   <script src="https://www.unea.fr/sites/default/files/js/js_CHUU_K_7fVHejuB45SjmcuU0tkjYi7UZDvrIeVLLyyc.js">
#   </script>
#   <script src="https://www.unea.fr/sites/all/modules/custom/unea_ea/js/ea-list-map.js?qfc2p3">
#   </script>
#   <script src="https://www.unea.fr/sites/all/modules/custom/unea_ea/js/ea-list-filter.js?qfc2p3">
#   </script>
#   <script src="https://www.unea.fr/sites/all/libraries/gmaps/markerclusterer.min.js?qfc2p3">
#   </script>
#   <script src="https://www.unea.fr/sites/default/files/js/js_MpAXLlTZveMepWh7AYxqP1wTD3e9HE-SziWgF66jIwA.js">
#   </script>
#   <script src="https://www.unea.fr/sites/default/files/js/js_R9UbiVw2xuTUI0GZoaqMDOdX0lrZtgX-ono8RVOUEVc.js">
#   </script>
#   <script src="https://www.unea.fr/sites/default/files/js/js_WCv7KAN_srGKIr1Kzte2BbwMfxFT4FLfaMvm5gOEjQ4.js">
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create", "UA-5517453-1", {"cookieDomain":"auto"});ga("set", "anonymizeIp", true);ga("send", "pageview");
#   </script>
#   <script src="https://www.unea.fr/sites/default/files/js/js_coqZ-uRPfrRifLnighT-ttNxPQgp7MT7u6A9GkzbiUk.js">
#   </script>
#   <script src="https://www.unea.fr/sites/default/files/js/js_YK-oCo-kms9md7RRQ3PmovA3dHo5JhOMAE64NnZBwM8.js">
#   </script>
#   <script>
#    jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","autocomplete_limit":{"limit":"1"},"ajaxPageState":{"theme":"customer","theme_token":"NPeJz1cyJVMp5ZBYJrNLLUiZ7EuhVPTTfvaC2yB8B4w","jquery_version":"1.11","js":{"0":1,"1":1,"sites\/all\/modules\/contrib\/eu_cookie_compliance\/js\/eu_cookie_compliance.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery\/1.11\/jquery.min.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/contrib\/eu_cookie_compliance\/js\/jquery.cookie-1.4.1.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery.form\/3\/jquery.form.min.js":1,"sites\/all\/libraries\/chosen\/chosen.jquery.min.js":1,"sites\/all\/modules\/custom\/unea_ea\/js\/ea-list-map.js":1,"sites\/all\/modules\/custom\/unea_ea\/js\/ea-list-filter.js":1,"sites\/all\/libraries\/gmaps\/markerclusterer.min.js":1,"misc\/states.js":1,"misc\/form.js":1,"misc\/ajax.js":1,"sites\/all\/modules\/contrib\/jquery_update\/js\/jquery_update.js":1,"sites\/all\/modules\/contrib\/admin_menu\/admin_devel\/admin_devel.js":1,"sites\/all\/modules\/contrib\/async_js\/async_js.js":1,"public:\/\/languages\/fr_Y8bQTUXU11owbVH2KbhbB1RJRQnvSj71BsIwCGtbBdQ.js":1,"sites\/all\/modules\/custom\/ecedi_pager\/js\/pager.js":1,"sites\/all\/modules\/contrib\/fancybox\/fancybox.js":1,"sites\/all\/libraries\/fancybox\/source\/jquery.fancybox.pack.js":1,"sites\/all\/libraries\/fancybox\/lib\/jquery.mousewheel.pack.js":1,"misc\/jquery.cookie.js":1,"sites\/all\/modules\/custom\/prehome\/js\/prehome.js":1,"sites\/all\/modules\/contrib\/google_analytics\/googleanalytics.js":1,"2":1,"misc\/autocomplete.js":1,"sites\/all\/modules\/contrib\/search_api_autocomplete\/search_api_autocomplete.js":1,"misc\/progress.js":1,"sites\/all\/modules\/custom\/unea_specifics\/js\/unea_specifics.list_filter_behavior.js":1,"sites\/all\/modules\/contrib\/field_group\/field_group.js":1,"sites\/all\/modules\/contrib\/autocomplete_limit\/js\/autocomplete.limit.js":1,"sites\/all\/modules\/contrib\/chosen\/chosen.js":1,"sites\/all\/themes\/custom\/customer\/js\/jquery.fitvids.js":1,"sites\/all\/themes\/custom\/customer\/js\/chosen.jquery.min.js":1,"sites\/all\/themes\/custom\/customer\/..\/..\/..\/libraries\/mCustomScrollbar\/jquery.mCustomScrollbar.concat.min.js":1,"sites\/all\/themes\/custom\/customer\/js\/script.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"sites\/all\/libraries\/chosen\/chosen.css":1,"sites\/all\/modules\/contrib\/chosen\/css\/chosen-drupal.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/libraries\/fancybox\/source\/jquery.fancybox.css":1,"sites\/all\/modules\/custom\/prehome\/css\/prehome.css":1,"sites\/all\/themes\/custom\/customer\/css\/customer.css":1,"sites\/all\/modules\/contrib\/eu_cookie_compliance\/css\/eu_cookie_compliance.css":1,"sites\/all\/modules\/contrib\/search_api_autocomplete\/search_api_autocomplete.css":1,"0":1,"sites\/all\/themes\/custom\/ecedi\/system.menus.css":1,"sites\/all\/themes\/custom\/ecedi\/system.messages.css":1,"sites\/all\/themes\/custom\/ecedi\/system.theme.css":1,"sites\/all\/themes\/custom\/ecedi\/css\/ecedi.css":1,"sites\/all\/themes\/custom\/customer\/..\/..\/..\/libraries\/mCustomScrollbar\/jquery.mCustomScrollbar.css":1,"sites\/all\/themes\/custom\/customer\/css\/styles_customer.css":1}},"fancybox":[],"prehome":{"prehome_image_id":"1","prehome_image_name":"prehome_covid_19.jpg","prehome_max_view_times":"50000000","prehome_verbose_mode":"0","prehome_vertical_pos":0,"prehome_width":1288,"prehome_height":402,"prehome_horizontal_pos":0,"prehome_padding":0,"prehome_margin":20,"prehome_image_width":1288 ...
#   </script>
#   <!--[if lt IE 9]>
#     <script src="/sites/all/themes/contrib/zen/js/html5-respond.js"></script>
#     <![endif]-->
#   <!--[if lt IE 9]>
#     <script src="/sites/all/themes/custom/ecedi/js/ie.js"></script>
#   <![endif]-->
#  </head>
#  <body class="html not-front not-logged-in no-sidebars page-node page-node- page-node-22 node-type-page section-annuaire simple-page section-annuaire-des-entreprises-adaptees">
#   <p id="skip-link">
#    <a class="element-invisible element-focusable" href="#main-navigation">
#     Accéder au menu
#    </a>
#   </p>
#   <div id="page">
#    <header class="site-header" id="header" role="banner">
#     <div class="clearfix">
#      <div class="header-logo" id="logo">
#       <a class="back-home-link" href="/" rel="home" title="Accueil">
#        <img alt="UNEA - Union nationale des entreprises adaptées (retour à l'accueil)" class="logo-img" src="https://www.unea.fr/sites/all/themes/custom/customer/logo.png"/>
#       </a>
#      </div>
#      <div id="main-navigation">
#       <div class="menu-mobile">
#        <a class="button-burger" href="#" title="Menu">
#         <span>
#          Menu
#         </span>
#        </a>
#       </div>
#       <div class="region region-navigation">
#        <div class="block block-menu-block main-menu first odd" id="block-menu-block-1" role="navigation">
#         <div class="content">
#          <nav class="menu-block-wrapper menu-block-1 menu-name-main-menu parent-mlid-0 menu-level-1">
#           <ul class="menu">
#            <li class="menu__item is-expanded first expanded menu-mlid-703 rub-services nav-item depth-1">
#             <a class="menu__link main-menu-parent" href="/">
#              Nos services
#             </a>
#             <ul class="colonnes">
#              <li class="colonne">
#               <ul class="menu">
#                <li class="menu__item is-leaf first leaf menu-mlid-706 col-suivante nav-item depth-2">
#                 <a class="menu__link" href="/gpec">
#                  GPEC
#                 </a>
#                </li>
#                <li class="menu__item is-leaf leaf menu-mlid-707 nav-item depth-2">
#                 <a class="menu__link" href="/rse">
#                  RSE
#                 </a>
#                </li>
#                <li class="menu__item is-leaf is-parent leaf has-children menu-mlid-708 nav-item depth-2">
#                 <a class="menu__link" href="/service-juridique">
#                  Service juridique
#                 </a>
#                </li>
#                <li class="menu__item is-leaf is-parent leaf has-children menu-mlid-710 nav-item depth-2">
#                 <a class="menu__link" href="/filieres-metiers">
#                  Filières métiers
#                 </a>
#                </li>
#                <li class="menu__item is-leaf last leaf menu-mlid-930 nav-item depth-2">
#                 <a class="menu__link" href="https://www.unea.fr/la-place-de-marches">
#                  La place de marchés
#                 </a>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </li>
#            <li class="menu__item is-leaf leaf menu-mlid-833 rub-academy nav-item depth-1">
#             <a class="menu__link" href="/academie-unea">
#              Académie UNEA
#             </a>
#            </li>
#            <li class="menu__item is-leaf is-active-trail is-active leaf active-trail active menu-mlid-705 rub-search-ea nav-item depth-1 active">
#             <a class="menu__link is-active-trail active-trail active active" href="/annuaire-des-entreprises-adaptees" title="Rechercher une EA - Rubrique active">
#              Rechercher une EA
#             </a>
#            </li>
#            <li class="menu__item is-expanded last expanded menu-mlid-704 rub-info nav-item depth-1">
#             <a class="menu__link main-menu-parent" href="/">
#              S'informer
#             </a>
#             <ul class="colonnes">
#              <li class="colonne">
#               <ul class="menu">
#                <li class="menu__item is-leaf first leaf menu-mlid-711 col-suivante nav-item depth-2">
#                 <a class="menu__link" href="/agenda">
#                  Agenda
#                 </a>
#                </li>
#                <li class="menu__item is-leaf leaf menu-mlid-712 nav-item depth-2">
#                 <a class="menu__link" href="/actualites">
#                  Actualités
#                 </a>
#                </li>
#                <li class="menu__item is-leaf is-parent leaf has-children menu-mlid-713 nav-item depth-2">
#                 <a class="menu__link" href="/newsletters">
#                  Newsletters
#                 </a>
#                </li>
#                <li class="menu__item is-leaf leaf menu-mlid-950 nav-item depth-2">
#                 <a class="menu__link" href="/de-la-concertation-levolution-du-modele-ea">
#                  De la concertation à l'évolution du modèle EA
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="colonne">
#               <ul class="menu">
#                <li class="menu__item is-leaf leaf menu-mlid-714 col-suivante nav-item depth-2">
#                 <a class="menu__link" href="/chiffres-cles">
#                  Chiffres clés
#                 </a>
#                </li>
#                <li class="menu__item is-leaf leaf menu-mlid-715 nav-item depth-2">
#                 <a class="menu__link" href="/quest-ce-quune-entreprise-adaptee">
#                  Qu'est ce qu'une Entreprise Adaptée ?
#                 </a>
#                </li>
#                <li class="menu__item is-leaf last leaf menu-mlid-718 nav-item depth-2">
#                 <a class="menu__link" href="/europe-et-ea">
#                  Europe et EA
#                 </a>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </li>
#           </ul>
#          </nav>
#         </div>
#        </div>
#        <div class="block block-search-api-page header-search-bloc even" id="block-search-api-page-search-sitewide">
#         <div class="desktop">
#          <a class="link-menu link-search" href="#">
#           <span>
#            Recherche
#           </span>
#          </a>
#         </div>
#         <div class="content">
#          <form accept-charset="UTF-8" action="/annuaire-des-entreprises-adaptees?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;autocomplete_selected=&amp;form_build_id=form-qYY-_LbpYQE7EtvYA_TQaQlyQ0uNpAuJL0xts0cvpmg&amp;form_id=ecedi_list_filter_form" id="search-api-page-search-form-search-sitewide" method="post">
#           <div>
#            <a class="picto-close" href="#close">
#             close
#            </a>
#            <div class="form-item form-type-textfield form-item-keys-1">
#             <label class="element-invisible" for="edit-keys-1">
#              Entrez vos mots-clés
#             </label>
#             <input class="auto_submit form-text form-autocomplete" data-min-autocomplete-length="3" data-search-api-autocomplete-search="search_api_page_search_sitewide" id="edit-keys-1" maxlength="128" name="keys_1" placeholder="Entrez vos mots-clés" size="15" type="text" value=""/>
#             <input class="autocomplete" disabled="disabled" id="edit-keys-1-autocomplete" type="hidden" value="https://www.unea.fr/index.php?q=search_api_autocomplete/search_api_page_search_sitewide/-"/>
#            </div>
#            <input name="id" type="hidden" value="1"/>
#            <button class="form-submit" id="edit-submit-1" name="op" type="submit" value="Recherche">
#             Recherche
#            </button>
#            <input name="form_build_id" type="hidden" value="form-j2cJcUGUcjDIY61gZ266IMuFuV_KiAoc3PD-zd5FdT4"/>
#            <input name="form_id" type="hidden" value="search_api_page_search_form_search_sitewide"/>
#           </div>
#          </form>
#         </div>
#        </div>
#        <div class="block block-menu-block burger-menu last odd" id="block-menu-block-2" role="navigation">
#         <div class="desktop">
#          <a class="link-menu button-burger" href="#" title="Menu">
#           <span class="open">
#            Menu
#           </span>
#           <span class="close">
#            Fermer
#           </span>
#          </a>
#         </div>
#         <div class="content burger-menu-content">
#          <nav class="menu-block-wrapper menu-block-2 menu-name-menu-menu-burger parent-mlid-0 menu-level-1">
#           <ul class="menu">
#            <li class="menu__item is-expanded first expanded menu-mlid-720 first-col">
#             <a class="menu__link" href="/">
#              A propos
#             </a>
#             <ul class="menu">
#              <li class="menu__item is-leaf first leaf menu-mlid-815">
#               <a class="menu__link" href="/roles-et-missions">
#                Rôles et missions
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-727">
#               <a class="menu__link" href="/les-instances-associatives">
#                Les instances associatives
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-728">
#               <a class="menu__link" href="/lequipe">
#                L'équipe
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-832">
#               <a class="menu__link" href="/campagne-dadhesion-2020">
#                Adhérer à l'UNEA
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-859">
#               <a class="menu__link" href="/lunea-en-region">
#                L'UNEA en région
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-829">
#               <a class="menu__link" href="/carte-des-regions">
#                Carte des régions
#               </a>
#              </li>
#              <li class="menu__item is-leaf last leaf menu-mlid-926">
#               <a class="menu__link" href="/nos-partenaires-0">
#                Nos partenaires
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li class="menu__item is-expanded expanded menu-mlid-721">
#             <a class="menu__link" href="/">
#              Acteur économique
#             </a>
#             <ul class="menu">
#              <li class="menu__item is-leaf first leaf menu-mlid-816">
#               <a class="menu__link" href="/pourquoi-avoir-recours-une-entreprise-adaptee">
#                Pourquoi avoir recours à une EA
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-733">
#               <a class="menu__link" href="/devenez-partenaire-de-lunea">
#                Devenir partenaire de l'UNEA
#               </a>
#              </li>
#              <li class="menu__item is-leaf is-active leaf active menu-mlid-734">
#               <a class="menu__link active" href="/annuaire-des-entreprises-adaptees">
#                Rechercher une entreprise adaptée
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-963">
#               <a class="menu__link" href="/handi-market-bourgogne-franche-comte">
#                HANDI MARKET
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-964">
#               <a class="menu__link" href="/inclusive-tour">
#                Inclusive Tour
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-927">
#               <a class="menu__link" href="/lobligation-demploi-de-travailleurs-handicapes">
#                L'obligation d'emploi de travailleurs handicapés
#               </a>
#              </li>
#              <li class="menu__item is-leaf last leaf menu-mlid-937">
#               <a class="menu__link" href="https://www.unea.fr/taxe-apprentissage-2018">
#                Taxe d'Apprentissage
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li class="menu__item is-expanded expanded menu-mlid-722">
#             <a class="menu__link" href="/">
#              Entreprise adaptée
#             </a>
#             <ul class="menu">
#              <li class="menu__item is-leaf first leaf menu-mlid-736">
#               <a class="menu__link" href="/participer-au-reseau">
#                Participer au réseau
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-737">
#               <a class="menu__link" href="/developper-mon-entreprise-adaptee">
#                Développer mon entreprise adaptée
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-868">
#               <a class="menu__link" href="/veille-sur-les-marches-publics">
#                Veille sur les marchés publics
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-929">
#               <a class="menu__link" href="https://www.unea.fr/la-place-de-marches">
#                La Place de marchés
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-972">
#               <a class="menu__link" href="/le-cdd-tremplin-en-entreprise-adaptee">
#                Le CDD Tremplin en Entreprise Adaptée
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-974">
#               <a class="menu__link" href="/covid-19-dossier-complet-pour-faire-face-la-situation">
#                COVID 19 - Dossier complet pour faire face à la situation
#               </a>
#              </li>
#              <li class="menu__item is-leaf leaf menu-mlid-973">
#               <a class="menu__link" href="/la-place-de-marches">
#                La place de marchés
#               </a>
#              </li>
#              <li class="menu__item is-leaf last leaf menu-mlid-936">
#               <a class="menu__link" href="https://www.unea.fr/taxe-apprentissage-2018">
#                Taxe d'Apprentissage
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li class="menu__item is-expanded is-active-trail expanded active-trail menu-mlid-723">
#             <a class="menu__link is-active-trail active-trail" href="/">
#              Travailleur handicapé
#             </a>
#             <ul class="menu">
#              <li class="menu__item is-leaf first leaf menu-mlid-739">
#               <a class="menu__link" href="/procedure-de-recrutement-en-ea">
#                Connaître la procédure de recrutement en entreprise adaptée
#               </a>
#              </li>
#              <li class="menu__item is-leaf is-active-trail is-active leaf active-trail active menu-mlid-740">
#               <a class="menu__link is-active-trail active-trail active" href="/annuaire-des-entreprises-adaptees">
#                Repérer les entreprises adaptées
#               </a>
#              </li>
#              <li class="menu__item is-leaf last leaf menu-mlid-928">
#               <a class="menu__link" href="https://www.unea.fr/offres-demploi-en-entreprise-adaptee">
#                Offres d'emploi en entreprises adaptées
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li class="menu__item is-expanded last expanded menu-mlid-724">
#             <a class="menu__link" href="/">
#              Journaliste
#             </a>
#             <ul class="menu">
#              <li class="menu__item is-leaf first leaf menu-mlid-730">
#               <a class="menu__link" href="/espace-presse">
#                Nos publications
#               </a>
#              </li>
#              <li class="menu__item is-leaf last leaf menu-mlid-725">
#               <a class="menu__link" href="/espace-presse">
#                Consulter l'espace presse
#               </a>
#              </li>
#             </ul>
#            </li>
#           </ul>
#          </nav>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!-- /outer-wrap -->
#     </div>
#     <!-- /outer-wrap -->
#    </header>
#    <div class="outer-wrap">
#     <nav class="breadcrumb" role="navigation">
#      <span class="element-invisible">
#       You are here
#      </span>
#      <ol>
#       <li>
#        <a href="/">
#         Accueil
#        </a>
#       </li>
#       <li>
#        Annuaire des Entreprises Adaptées
#       </li>
#      </ol>
#     </nav>
#    </div>
#    <div id="main-content">
#     <div class="single-column" id="content" role="main">
#      <div class="main-content outer-wrap">
#       <div class="inner-wrap-list">
#        <article about="/annuaire-des-entreprises-adaptees" class="main-node node-22 node node-page view-mode-full clearfix" typeof="foaf:Document">
#         <div class="inner-wrap">
#          <header>
#           <h1>
#            Annuaire des Entreprises Adaptées
#           </h1>
#          </header>
#          <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#          <div class="field field-name-field-teaser field-type-text-long field-label-hidden">
#           <div class="field-items">
#            <div class="field-item even">
#             Le seul annuaire reprenant l'ensemble des Entreprises Adaptées du territoire
#            </div>
#           </div>
#          </div>
#          <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#          <div class="field field-name-body field-type-text-with-summary field-label-hidden">
#           <div class="field-items">
#            <div class="field-item even" property="content:encoded">
#             <p>
#              La vitrine des Entreprises Adaptées
#              <br/>
#              Une mise à jour régulière de l'ensemble des informations
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </article>
#        <div class="block block-ecedi-list entreprise-filter even" id="block-ecedi-list-list-adapted-company-filter">
#         <h2 class="block__title block-title">
#          Rechercher une entreprise adaptée
#         </h2>
#         <div class="content">
#          <form accept-charset="UTF-8" action="/annuaire-des-entreprises-adaptees?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;autocomplete_selected=&amp;form_build_id=form-qYY-_LbpYQE7EtvYA_TQaQlyQ0uNpAuJL0xts0cvpmg&amp;form_id=ecedi_list_filter_form" id="ecedi-list-filter-form" method="get">
#           <div>
#            <fieldset class="form-wrapper" id="edit-fieldset">
#             <div class="fieldset-wrapper">
#              <div id="dropdown-sectors-activity-replace">
#               <div class="form-wrapper" id="edit-sectors-activity">
#                <div class="form-item form-type-select form-item-sector">
#                 <label for="edit-sector">
#                  Par secteur
#                 </label>
#                 <select class="chosen-enable form-select" data-placeholder="Choisir un secteur d'activités" id="edit-sector" name="sector">
#                  <option value="0">
#                  </option>
#                  <option value="364888">
#                   Agriculture, environnement, Espaces Verts
#                  </option>
#                  <option value="364912">
#                   Alimentation, production alimentaire
#                  </option>
#                  <option value="364925">
#                   Batiment et travaux publics
#                  </option>
#                  <option value="364944">
#                   Bien-être
#                  </option>
#                  <option value="364948">
#                   Blanchisserie
#                  </option>
#                  <option value="364957">
#                   collecte, traitement et recyclage des déchets
#                  </option>
#                  <option value="364967">
#                   Commerce, distribution
#                  </option>
#                  <option value="364980">
#                   Conciergerie
#                  </option>
#                  <option value="364983">
#                   Eco-batiment / energies / energies renouvelables
#                  </option>
#                  <option value="364995">
#                   Gestion, administration, informatique
#                  </option>
#                  <option value="365031">
#                   Hotellerie, location de salles, tourisme
#                  </option>
#                  <option value="365046">
#                   Impression, communication, évènementiel
#                  </option>
#                  <option value="365086">
#                   Médical et para-médical
#                  </option>
#                  <option value="365091">
#                   Menuiserie
#                  </option>
#                  <option value="365101">
#                   Mise à disposition de personnel
#                  </option>
#                  <option value="365104">
#                   Nettoyage et Hygiène des locaux
#                  </option>
#                  <option value="365115">
#                   Prestations Intellectuelles
#                  </option>
#                  <option value="365125">
#                   Production et sous traitance industrielle
#                  </option>
#                  <option value="365160">
#                   réparation, dépannage, SAV
#                  </option>
#                  <option value="365171">
#                   Restauration
#                  </option>
#                  <option value="365179">
#                   Textile, ameublement, artisanat d'Art
#                  </option>
#                  <option value="365190">
#                   Transport, logistique, conditionnement
#                  </option>
#                 </select>
#                </div>
#                <div id="container-choice">
#                 <div class="form-wrapper" id="edit-container">
#                  <div id="content-sector">
#                   <div class="form-wrapper" id="edit-container-sector">
#                    <div id="dropdown-sector-makup-replace">
#                    </div>
#                    <div id="dropdown-sector-reset-replace">
#                     <button class="form-submit" id="edit-sector-reset" name="op" type="submit" value="close">
#                      close
#                     </button>
#                    </div>
#                   </div>
#                  </div>
#                  <div id="dropdown-section-replace">
#                   <div class="form-item form-type-select form-item-section">
#                    <label for="edit-section">
#                     Choisir une section
#                    </label>
#                    <select class="chosen-enable form-select" data-placeholder="Choisir une section" id="edit-section" name="section">
#                     <option value="0">
#                     </option>
#                    </select>
#                   </div>
#                  </div>
#                  <div class="form-item form-type-select form-item-activity">
#                   <label for="edit-activity">
#                    Choisir une activité
#                   </label>
#                   <select class="chosen-enable form-select" data-placeholder="Choisir une activité" id="edit-activity" name="activity">
#                    <option selected="selected" value="0">
#                    </option>
#                   </select>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="form-item form-type-textfield form-item-keyword">
#               <label for="edit-keyword">
#                Nom de l'entreprise
#               </label>
#               <input class="form-text form-autocomplete" data-limit="3" id="edit-keyword" maxlength="128" name="keyword" size="20" type="text" value=""/>
#               <input class="autocomplete" disabled="disabled" id="edit-keyword-autocomplete" type="hidden" value="https://www.unea.fr/index.php?q=autocomplete/company-name"/>
#              </div>
#              <div class="form-item form-type-select form-item-region">
#               <label for="edit-region">
#                Par régions
#               </label>
#               <select class="form-select" id="edit-region" name="region">
#                <option selected="selected" value="">
#                 Sélectionner une région
#                </option>
#                <option value="2">
#                 Auvergne Rhône-Alpes
#                </option>
#                <option value="3">
#                 Bourgogne Franche-Comté
#                </option>
#                <option value="4">
#                 Bretagne
#                </option>
#                <option value="5">
#                 Centre Val de Loire
#                </option>
#                <option value="6">
#                 Corse
#                </option>
#                <option value="7">
#                 Grand Est
#                </option>
#                <option value="14">
#                 Guadeloupe
#                </option>
#                <option value="15">
#                 Guyane
#                </option>
#                <option value="8">
#                 Hauts-de-France
#                </option>
#                <option value="9">
#                 Île-de-France
#                </option>
#                <option value="16">
#                 La Réunion
#                </option>
#                <option value="17">
#                 Martinique
#                </option>
#                <option value="11">
#                 Normandie
#                </option>
#                <option value="1">
#                 Nouvelle Aquitaine
#                </option>
#                <option value="10">
#                 Occitanie
#                </option>
#                <option value="12">
#                 Pays de la Loire
#                </option>
#                <option value="13">
#                 Provence Alpes Côte d\Azur
#                </option>
#               </select>
#              </div>
#              <div class="form-actions form-wrapper" id="edit-actions">
#               <button class="ea-filter-submit icon icon-search form-submit" id="edit-submit" name="op" type="submit" value="Suivez le guide">
#                Suivez le guide
#               </button>
#               <a class="form-reset active" href="/annuaire-des-entreprises-adaptees">
#                Réinitialiser les filtres
#               </a>
#              </div>
#             </div>
#            </fieldset>
#            <input id="edit-lat" name="lat" type="hidden" value=""/>
#            <input id="edit-lng" name="lng" type="hidden" value=""/>
#            <input id="edit-autocomplete-selected" name="autocomplete_selected" type="hidden" value=""/>
#            <input name="form_build_id" type="hidden" value="form-E2dGAxpwYSvxtRX6spzSke52q9hFx99Q0bN344KiOgQ"/>
#            <input name="form_id" type="hidden" value="ecedi_list_filter_form"/>
#           </div>
#          </form>
#         </div>
#        </div>
#        <div class="block block-ecedi-list list-entreprise odd" id="block-ecedi-list-list-adapted-company">
#         <div class="content">
#          <div class="ecedi-list-wrapper" id="ecedi-list-list_adapted_company">
#           <div class="list-content">
#            <p class="result-info">
#             <span>
#              826
#             </span>
#             résultats correspondent à votre recherche
#            </p>
#            <div class="marker-legend">
#             <ul>
#              <li>
#               <div class="marker-legend-item">
#                <img alt="" src="sites/all/themes/custom/customer/images/ea-marker.svg"/>
#                <p>
#                 Entreprise adaptée
#                </p>
#               </div>
#              </li>
#              <li>
#               <div class="marker-legend-item">
#                <img alt="" src="sites/all/themes/custom/customer/images/ea-marker-13419.svg"/>
#                <p>
#                 EA - Etablissement secondaire
#                </p>
#               </div>
#              </li>
#              <li>
#               <div class="marker-legend-item">
#                <img alt="" src="sites/all/themes/custom/customer/images/ea-marker-14356.svg"/>
#                <p>
#                 EATT - Entreprise adaptée de travail temporaire
#                </p>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="list-result">
#             <ul class="ecedi-list-content list_adapted_company">
#              <li>
#               <div class="entreprise-adaptee node-adapted-company node-933596">
#                <div class="ea-logos">
#                 <img alt="" class="logo_tremplin" src="sites/all/themes/custom/customer/images/cdd-tremplin.png"/>
#                 <img alt="Cette entreprise adaptée adhère à l'UNEA" class="logo_membership" src="https://www.unea.fr/sites/all/themes/custom/customer/images/logo_unea_membership_teaser.png" typeof="foaf:Image"/>
#                </div>
#                <div class="content-left">
#                 <div class="field field-name-title field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even" property="dc:title">
#                    <h2>
#                     <a href="/fmea-hauts-de-france?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;form_id=ecedi_list_filter_form">
#                      FMEA HAUTS DE FRANCE
#                     </a>
#                    </h2>
#                   </div>
#                  </div>
#                 </div>
#                 <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#                 <div class="field field-name-field-zipcode-town field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even">
#                    <p>
#                     02400 CHATEAU THIERRY
#                    </p>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="field-sectors">
#                 <div class="item-list">
#                  <h3>
#                   Secteurs d'activité
#                  </h3>
#                  <ul>
#                   <li class="first last">
#                    Transport, logistique, conditionnement
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li>
#               <div class="entreprise-adaptee node-adapted-company node-933578">
#                <div class="ea-logos">
#                 <img alt="" class="logo_tremplin" src="sites/all/themes/custom/customer/images/cdd-tremplin.png"/>
#                 <img alt="Cette entreprise adaptée adhère à l'UNEA" class="logo_membership" src="https://www.unea.fr/sites/all/themes/custom/customer/images/logo_unea_membership_teaser.png" typeof="foaf:Image"/>
#                </div>
#                <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#                <div class="field field-name-field-logo field-type-image field-label-hidden">
#                 <div class="field-items">
#                  <div class="field-item even">
#                   <img alt="" height="30" src="https://www.unea.fr/sites/default/files/styles/entreprise_logo_liste/public/logo_ea_3819.JPG?itok=ajFGPMT1" typeof="foaf:Image" width="94"/>
#                  </div>
#                 </div>
#                </div>
#                <div class="content-left">
#                 <div class="field field-name-title field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even" property="dc:title">
#                    <h2>
#                     <a href="/etp-synergie?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;form_id=ecedi_list_filter_form">
#                      ETP SYNERGIE
#                     </a>
#                    </h2>
#                   </div>
#                  </div>
#                 </div>
#                 <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#                 <div class="field field-name-field-zipcode-town field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even">
#                    <p>
#                     39100 DOLE
#                    </p>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="field-sectors">
#                 <div class="item-list">
#                  <h3>
#                   Secteurs d'activité
#                  </h3>
#                  <ul>
#                   <li class="first">
#                    Nettoyage et Hygiène des locaux
#                   </li>
#                   <li>
#                    Production et sous traitance industrielle
#                   </li>
#                   <li>
#                    Transport, logistique, conditionnement
#                   </li>
#                   <li class="last">
#                    Mise à disposition de personnel
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li>
#               <div class="entreprise-adaptee node-adapted-company node-933577">
#                <div class="ea-logos">
#                 <img alt="" class="logo_tremplin" src="sites/all/themes/custom/customer/images/cdd-tremplin.png"/>
#                 <img alt="Cette entreprise adaptée adhère à l'UNEA" class="logo_membership" src="https://www.unea.fr/sites/all/themes/custom/customer/images/logo_unea_membership_teaser.png" typeof="foaf:Image"/>
#                </div>
#                <div class="content-left">
#                 <div class="field field-name-title field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even" property="dc:title">
#                    <h2>
#                     <a href="/etp-st-james?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;form_id=ecedi_list_filter_form">
#                      ETP ST JAMES
#                     </a>
#                    </h2>
#                   </div>
#                  </div>
#                 </div>
#                 <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#                 <div class="field field-name-field-zipcode-town field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even">
#                    <p>
#                     50240 ST JAMES
#                    </p>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="field-sectors">
#                 <div class="item-list">
#                  <h3>
#                   Secteurs d'activité
#                  </h3>
#                  <ul>
#                   <li class="first">
#                    Menuiserie
#                   </li>
#                   <li>
#                    Transport, logistique, conditionnement
#                   </li>
#                   <li>
#                    Nettoyage et Hygiène des locaux
#                   </li>
#                   <li class="last">
#                    Agriculture, environnement, Espaces Verts
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li>
#               <div class="entreprise-adaptee node-adapted-company node-933576">
#                <div class="ea-logos">
#                 <img alt="" class="logo_tremplin" src="sites/all/themes/custom/customer/images/cdd-tremplin.png"/>
#                 <img alt="Cette entreprise adaptée adhère à l'UNEA" class="logo_membership" src="https://www.unea.fr/sites/all/themes/custom/customer/images/logo_unea_membership_teaser.png" typeof="foaf:Image"/>
#                </div>
#                <div class="content-left">
#                 <div class="field field-name-title field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even" property="dc:title">
#                    <h2>
#                     <a href="/ethap-npc?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;form_id=ecedi_list_filter_form">
#                      ETHAP NPC
#                     </a>
#                    </h2>
#                   </div>
#                  </div>
#                 </div>
#                 <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#                 <div class="field field-name-field-zipcode-town field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even">
#                    <p>
#                     59287 GUESNAIN
#                    </p>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="field-sectors">
#                 <div class="item-list">
#                  <h3>
#                   Secteurs d'activité
#                  </h3>
#                  <ul>
#                   <li class="first">
#                    Agriculture, environnement, Espaces Verts
#                   </li>
#                   <li>
#                    Batiment et travaux publics
#                   </li>
#                   <li>
#                    collecte, traitement et recyclage des déchets
#                   </li>
#                   <li>
#                    Gestion, administration, informatique
#                   </li>
#                   <li>
#                    Impression, communication, évènementiel
#                   </li>
#                   <li class="last">
#                    Transport, logistique, conditionnement
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li>
# ...
#                    </p>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="field-sectors">
#                 <div class="item-list">
#                  <h3>
#                   Secteurs d'activité
#                  </h3>
#                  <ul>
#                   <li class="first">
#                    Agriculture, environnement, Espaces Verts
#                   </li>
#                   <li>
#                    Transport, logistique, conditionnement
#                   </li>
#                   <li>
#                    Production et sous traitance industrielle
#                   </li>
#                   <li>
#                    réparation, dépannage, SAV
#                   </li>
#                   <li class="last">
#                    Textile, ameublement, artisanat d'Art
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li>
#               <div class="entreprise-adaptee node-adapted-company node-933357">
#                <div class="ea-logos">
#                </div>
#                <div class="content-left">
#                 <div class="field field-name-title field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even" property="dc:title">
#                    <h2>
#                     <a href="/cdtd-frere-frances?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;form_id=ecedi_list_filter_form">
#                      CDTD FRERE FRANCES
#                     </a>
#                    </h2>
#                   </div>
#                  </div>
#                 </div>
#                 <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#                 <div class="field field-name-field-zipcode-town field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even">
#                    <p>
#                     44300 NANTES
#                    </p>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="field-sectors">
#                 <div class="item-list">
#                  <h3>
#                   Secteurs d'activité
#                  </h3>
#                  <ul>
#                   <li class="first last">
#                    Textile, ameublement, artisanat d'Art
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li>
#               <div class="entreprise-adaptee node-adapted-company node-933735">
#                <div class="ea-logos">
#                </div>
#                <div class="content-left">
#                 <div class="field field-name-title field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even" property="dc:title">
#                    <h2>
#                     <a href="/lmg-bois?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;form_id=ecedi_list_filter_form">
#                      LMG BOIS
#                     </a>
#                    </h2>
#                   </div>
#                  </div>
#                 </div>
#                 <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#                 <div class="field field-name-field-zipcode-town field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even">
#                    <p>
#                     59560 COMINES
#                    </p>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="field-sectors">
#                 <div class="item-list">
#                  <h3>
#                   Secteurs d'activité
#                  </h3>
#                  <ul>
#                   <li class="first last">
#                    Menuiserie
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li>
#               <div class="entreprise-adaptee node-adapted-company node-933734">
#                <div class="ea-logos">
#                </div>
#                <div class="content-left">
#                 <div class="field field-name-title field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even" property="dc:title">
#                    <h2>
#                     <a href="/lmdes?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;form_id=ecedi_list_filter_form">
#                      LMDES
#                     </a>
#                    </h2>
#                   </div>
#                  </div>
#                 </div>
#                 <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#                 <div class="field field-name-field-zipcode-town field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even">
#                    <p>
#                     26190 ST JEAN EN ROYANS
#                    </p>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="field-sectors">
#                 <div class="item-list">
#                  <h3>
#                   Secteurs d'activité
#                  </h3>
#                  <ul>
#                   <li class="first">
#                    Gestion, administration, informatique
#                   </li>
#                   <li>
#                    Impression, communication, évènementiel
#                   </li>
#                   <li>
#                    collecte, traitement et recyclage des déchets
#                   </li>
#                   <li>
#                    Production et sous traitance industrielle
#                   </li>
#                   <li>
#                    Transport, logistique, conditionnement
#                   </li>
#                   <li class="last">
#                    Mise à disposition de personnel
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li>
#               <div class="entreprise-adaptee node-adapted-company node-933733">
#                <div class="ea-logos">
#                </div>
#                <div class="content-left">
#                 <div class="field field-name-title field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even" property="dc:title">
#                    <h2>
#                     <a href="/limprimerie-solidaire?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;form_id=ecedi_list_filter_form">
#                      L'IMPRIMERIE SOLIDAIRE
#                     </a>
#                    </h2>
#                   </div>
#                  </div>
#                 </div>
#                 <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#                 <div class="field field-name-field-zipcode-town field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even">
#                    <p>
#                     53470 MARTIGNE SUR MAYENNE
#                    </p>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="field-sectors">
#                 <div class="item-list">
#                  <h3>
#                   Secteurs d'activité
#                  </h3>
#                  <ul>
#                   <li class="first last">
#                    Impression, communication, évènementiel
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li>
#               <div class="entreprise-adaptee node-adapted-company node-933724">
#                <div class="ea-logos">
#                </div>
#                <div class="content-left">
#                 <div class="field field-name-title field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even" property="dc:title">
#                    <h2>
#                     <a href="/les-blanchisseries-severoises?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;form_id=ecedi_list_filter_form">
#                      LES BLANCHISSERIES SEVEROISES
#                     </a>
#                    </h2>
#                   </div>
#                  </div>
#                 </div>
#                 <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#                 <div class="field field-name-field-zipcode-town field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even">
#                    <p>
#                     36160 STE SEVERE SUR INDRE
#                    </p>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="field-sectors">
#                 <div class="item-list">
#                  <h3>
#                   Secteurs d'activité
#                  </h3>
#                  <ul>
#                   <li class="first last">
#                    Blanchisserie
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li>
#               <div class="entreprise-adaptee node-adapted-company node-933547">
#                <div class="ea-logos">
#                </div>
#                <div class="content-left">
#                 <div class="field field-name-title field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even" property="dc:title">
#                    <h2>
#                     <a href="/entreprise-adaptee-loxy?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;form_id=ecedi_list_filter_form">
#                      ENTREPRISE ADAPTEE LOXY
#                     </a>
#                    </h2>
#                   </div>
#                  </div>
#                 </div>
#                 <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#                 <div class="field field-name-field-zipcode-town field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even">
#                    <p>
#                     95310 ST OUEN L AUMONE
#                    </p>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="field-sectors">
#                 <div class="item-list">
#                  <h3>
#                   Secteurs d'activité
#                  </h3>
#                  <ul>
#                   <li class="first last">
#                    collecte, traitement et recyclage des déchets
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li>
#               <div class="entreprise-adaptee node-adapted-company node-933694">
#                <div class="ea-logos">
#                </div>
#                <div class="content-left">
#                 <div class="field field-name-title field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even" property="dc:title">
#                    <h2>
#                     <a href="/lea-de-champagne?sector=0&amp;section=0&amp;activity=0&amp;keyword=&amp;region=&amp;lat=&amp;lng=&amp;form_id=ecedi_list_filter_form">
#                      LEA DE CHAMPAGNE
#                     </a>
#                    </h2>
#                   </div>
#                  </div>
#                 </div>
#                 <!--
# THIS FILE IS NOT USED AND IS HERE AS A STARTING POINT FOR CUSTOMIZATION ONLY.
# See http://api.drupal.org/api/function/theme_field/7 for details.
# After copying this file to your theme's folder and customizing it, remove this
# HTML comment.
# -->
#                 <div class="field field-name-field-zipcode-town field-type-ds field-label-hidden">
#                  <div class="field-items">
#                   <div class="field-item even">
#                    <p>
#                     51100 REIMS
#                    </p>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="field-sectors">
#                 <div class="item-list">
#                  <h3>
#                   Secteurs d'activité
#                  </h3>
#                  <ul>
#                   <li class="first last">
#                    Impression, communication, évènementiel
#                   </li>
#                  </ul>
#                 </div>
#                </div>
#               </div>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="block block-ecedi-utils map-entreprise last even" id="block-ecedi-utils-uneaeasearchmapblock">
#         <div class="content">
#          <div id="ea-map">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <footer id="site-footer">
#     <div class="block last" id="footer">
#      <div class="outer-wrap">
#       <div class="region region-bottom">
#        <div class="block block-menu footer-left first odd" id="block-menu-menu-footer-left" role="navigation">
#         <div class="content">
#          <ul class="menu">
#           <li class="menu__item is-leaf first leaf">
#            <a class="menu__link" href="/contactez-nous">
#             Contactez-nous
#            </a>
#           </li>
#           <li class="menu__item is-leaf last leaf">
#            <a class="menu__link" href="/accessibilite">
#             Accessibilité
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="block block-menu footer-right last even" id="block-menu-menu-footer-right" role="navigation">
#         <div class="content">
#          <ul class="menu">
#           <li class="menu__item is-leaf first leaf">
#            <a class="menu__link" href="/sitemap">
#             Plan du site
#            </a>
#           </li>
#           <li class="menu__item is-leaf last leaf">
#            <a class="menu__link" href="/mentions-legales">
#             Mentions légales
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <script>
#    function euCookieComplianceLoadScripts() {}
#   </script>
#   <script>
#    var eu_cookie_compliance_cookie_name = "";
#   </script>
#   <script src="https://www.unea.fr/sites/default/files/js/js_4MRGjqSerJEQxet46pdKTifSYprPwyhoaSNKNoRsFw4.js">
#   </script>
#  </body>
# </html>

# %%
# nom des entreprises et url OK

ListNomEntreprise = []
ListUrlEntreprise = []

for Nom in soupurl.find_all('div', class_='field field-name-title field-type-ds field-label-hidden'):
    
    #NomEntreprise = Nom.div.div.h2.a.text
    #print(NomEntreprise)
    ListNomEntreprise.append(Nom.div.div.h2.a.text)
    
    href1=str(Nom.div.div.h2.a.attrs)
    hrefEntreprise = 'https://www.unea.fr' + href1[10:-2]
    #print(hrefEntreprise)
    ListUrlEntreprise.append(hrefEntreprise)

#ListNomEntreprise
#ListUrlEntreprise
    
df = pd.DataFrame({'Entreprise': ListNomEntreprise, 'URL': ListUrlEntreprise})
df
# Out:
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
# [826 rows x 2 columns]

# %%
# nom des localisation OK

ListLieuEntreprise=[]

for Lieu in soupurl.find_all('div', class_='field field-name-field-zipcode-town field-type-ds field-label-hidden'):
    LieuEntreprise = Lieu.text
    LieuEntreprise = re.sub('\n', '', LieuEntreprise)
    #print(LieuEntreprise)
    ListLieuEntreprise.append(LieuEntreprise)

#ListLieuEntreprise

df['Localisation']=ListLieuEntreprise
print(len(df))
df
# Out:
# 826
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
# [826 rows x 3 columns]

# %%
'''

# nom des activités KO

ListActiviteEntreprise = []

for activite in soupurl.find_all('div', class_='field-sectors'):
    activiteEntreprise = activite.text
    #activiteEntreprise = re.sub('\n', '', activiteEntreprise)
    #print(activiteEntreprise)
    ListActiviteEntreprise.append(activiteEntreprise)
    
ListActiviteEntreprise
print(len(ListActiviteEntreprise))

#df['Activites']=ListActiviteEntreprise
#df

'''
# Out:
# 808

# %% [markdown]
# ### Partie 2 : récupération des détails

# %%
'''

#all_urls = csv.reader(open('https://www.dropbox.com/s/e24lt6acpg7z7pg/dataminer.csv'))

with open('dataminer.csv', 'r') as csv_file :
    csv_reader = csv.reader(csv_file)
    next(csv_reader) # pour ne pas prendre la première ligne de titres 
    for line in csv_reader :
        i=str(line[0])
        #print(i)
        r=requests.get(i)
        soup = BeautifulSoup(r.content)

'''

# %%
'''

#r1=requests.get('https://www.unea.fr/entreprise-adaptee-le-vernoy?sector=0&section=0&activity=0&keyword=&region=&lat=&lng=&form_id=ecedi_list_filter_form').text
#r1=requests.get('https://www.unea.fr/etape-auvergne-43?sector=0&section=0&activity=0&keyword=&region=&lat=&lng=&form_id=ecedi_list_filter_form').text
#r1=requests.get('https://www.unea.fr/fastroad-lyon?sector=0&section=0&activity=0&keyword=&region=&lat=&lng=&form_id=ecedi_list_filter_form').text
#r1=requests.get('https://www.unea.fr/ethap-npc?sector=0&section=0&activity=0&keyword=&region=&lat=&lng=&form_id=ecedi_list_filter_form').text
#r1=requests.get('https://www.unea.fr/fat-orsac?sector=0&section=0&activity=0&keyword=&region=&lat=&lng=&form_id=ecedi_list_filter_form').text
#r1=requests.get('https://www.unea.fr/entreprise-adaptee-les-4-vents-apajh-95?sector=0&section=0&activity=0&keyword=&region=&lat=&lng=&form_id=ecedi_list_filter_form').text
r1=requests.get('https://www.unea.fr/entreprise-adaptee-lou-jas?sector=0&section=0&activity=0&keyword=&region=&lat=&lng=&form_id=ecedi_list_filter_form').text


    
soup1 = BeautifulSoup(r1)

'''

# %%
ListactiviteResume = []

for i in range(len(ListUrlEntreprise)):
    
    #print(i)
    #r=requests.get(ListUrlEntreprise[i])
    #soup = BeautifulSoup(r)
    #print(soup.prettify())
    
    url=ListUrlEntreprise[i]
    source = urllib.request.urlopen(url).read()
    soup = bs4.BeautifulSoup(source)


    try : 
        activite_resume = soup.find(class_="field field-name-body field-type-text-with-summary field-label-hidden").text
        activite_resume = re.sub('\n', '', activite_resume)
        #print(activite_resume)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        activite_resume=("NR")
        #print(activite_resume)
    ListactiviteResume.append(activite_resume)

df["ActiviteResume"] = ListactiviteResume
#print(len(df))
df
# Out:
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation  \
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
#                                         ActiviteResume
# 0                                                   NR
# 1    L'Entreprise Adaptée ETAPES fabrique principal...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821  LMDES une entreprise pas ordinaire pour des éq...
# 822                                                 NR
# 823  Association créée en Janvier 2012 dont l'activ...
# 824                                                 NR
# 825                                                 NR
#
# [826 rows x 4 columns]

# %%
#df.iloc[50:60,:]
#df.loc[df['ActiviteResume']!="NR", :]

# %%
# activité OK


ListActiviteDetails = []

for i in range(len(ListUrlEntreprise)):
    
    #print(i)
    #r=requests.get(ListUrlEntreprise[i])
    #soup = BeautifulSoup(r)
    #print(soup.prettify())
    
    url=ListUrlEntreprise[i]
    source = urllib.request.urlopen(url).read()
    soup = bs4.BeautifulSoup(source)

    
    try : 
        activite_details=soup.find('div', class_="field-sectors").ul.text
        activite_details = re.sub('\n', '', activite_details)
        #print(activite_details)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        activite_details=("NR")
        #print(activite_details)
    ListActiviteDetails.append(activite_details)

df["ActiviteDetails"] = ListActiviteDetails
#print(len(df))
df
# Out:
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation  \
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
#                                         ActiviteResume  \
# 0                                                   NR
# 1    L'Entreprise Adaptée ETAPES fabrique principal...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821  LMDES une entreprise pas ordinaire pour des éq...
# 822                                                 NR
# 823  Association créée en Janvier 2012 dont l'activ...
# 824                                                 NR
# 825                                                 NR
#
#                                        ActiviteDetails
# 0    Transport, logistique, conditionnementLogistiq...
# 1    Nettoyage et Hygiène des locauxNettoyage et Hy...
# 2    MenuiserieBoisGestion de scierieMenuiseriefabr...
# 3    Agriculture, environnement, Espaces VertsEntre...
# 4    Agriculture, environnement, Espaces VertsEntre...
# ..                                                 ...
# 821  Gestion, administration, informatiqueTravaux a...
# 822  Impression, communication, évènementielImpress...
# 823  BlanchisserieBlanchisserie IndustrielleLinge P...
# 824  collecte, traitement et recyclage des déchetsc...
# 825  Impression, communication, évènementielAudiovi...
#
# [826 rows x 5 columns]

# %%
'''
url=ListUrlEntreprise[4]
source = urllib.request.urlopen(url).read()
soup = bs4.BeautifulSoup(source)

    
try : 
    activite_details=soup.find('div', class_="field-sectors").ul.text
    activite_details = re.sub('\n', '', activite_details)
    #print(activite_details)
except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
    activite_details=("NR")
    #print(activite_details)
activite_details
'''
# Out:
# "Agriculture, environnement, Espaces VertsEntretien Aménagement Espaces VertsEntretien d'espaces vertsBlanchisserieBlanchisserie IndustrielleLinge PlatVêtements de travailBlanchisserieEntretien courant de LingeRestaurationRestaurationPlateaux Repastraiteurportage de repasNettoyage et Hygiène des locauxNettoyage et Hygiène des locauxNettoyage de locauxProduction et sous traitance industrielleAssemblageAssemblage manuelElectriqueCâblage Filaire (connectique, faisceaux….)mécaniquemécano soudureserrurerie / ferronerieTextile, ameublement, artisanat d'ArtTextile, ameublement, artisanat d'ArtConfection textile, coutureTransport, logistique, conditionnementLogistique, conditionnementconditionnement, déconditionnement (solide ou liquide)stockage, magasinage (préparation de commandes...)"

# %%
# adresse du fournisseur OK

ListAdresse1 = []
ListAdresse2 = []
ListAdresse3 = []

for i in range(len(ListUrlEntreprise)):
    
    #print(i)
    #r=requests.get(ListUrlEntreprise[i])
    #soup = BeautifulSoup(r)
    #print(soup.prettify())
    
    url=ListUrlEntreprise[i]
    source = urllib.request.urlopen(url).read()
    soup = bs4.BeautifulSoup(source)

    
    try : 
        adresse1=soup.find('div', class_="field field-name-field-address1 field-type-text field-label-hidden").text
        adresse1 = re.sub('\n', '', adresse1)
        #print(adresse1)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        adresse1=("NR")
        #print(adresse1)
    ListAdresse1.append(adresse1)

    try : 
        adresse2=soup.find('div', class_="field field-name-field-zipcode field-type-text field-label-hidden").text
        adresse2 = re.sub('\n', '', adresse2)
        #print(adresse2)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        adresse2=("NR")
        #print(adresse2)
    ListAdresse2.append(adresse2)
    
    try : 
        adresse3=soup.find('div', class_="field field-name-field-town field-type-text field-label-hidden").text
        adresse3 = re.sub('\n', '', adresse3)
        #print(adresse3)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        adresse3=("NR")
        #print(adresse3)
    ListAdresse3.append(adresse3)
    
    

df["Adresse1"] = ListAdresse1
df["Adresse2"] = ListAdresse2
df["Adresse3"] = ListAdresse3

#print(len(df))
df
# Out:
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation  \
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
#                                         ActiviteResume  \
# 0                                                   NR
# 1    L'Entreprise Adaptée ETAPES fabrique principal...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821  LMDES une entreprise pas ordinaire pour des éq...
# 822                                                 NR
# 823  Association créée en Janvier 2012 dont l'activ...
# 824                                                 NR
# 825                                                 NR
#
#                                        ActiviteDetails  \
# 0    Transport, logistique, conditionnementLogistiq...
# 1    Nettoyage et Hygiène des locauxNettoyage et Hy...
# 2    MenuiserieBoisGestion de scierieMenuiseriefabr...
# 3    Agriculture, environnement, Espaces VertsEntre...
# 4    Agriculture, environnement, Espaces VertsEntre...
# ..                                                 ...
# 821  Gestion, administration, informatiqueTravaux a...
# 822  Impression, communication, évènementielImpress...
# 823  BlanchisserieBlanchisserie IndustrielleLinge P...
# 824  collecte, traitement et recyclage des déchetsc...
# 825  Impression, communication, évènementielAudiovi...
#
#                    Adresse1 Adresse2              Adresse3
# 0             ZI DE L'OMOIS    02400       CHATEAU THIERRY
# 1    9 RUE HENRI JEANRENAUD    39100                  DOLE
# 2          RUE DE PONTORSON    50240              ST JAMES
# 3         130 ZI SAINT RENE    59287              GUESNAIN
# 4                  CHAUMONT    43360           VERGONGHEON
# ..                      ...      ...                   ...
# 821  1 IMPASSE DES PLANCHES    26190     ST JEAN EN ROYANS
# 822         1 RUE BELLATRIX    53470  MARTIGNE SUR MAYENNE
# 823     1 AVENUE D AUVERGNE    36160  STE SEVERE SUR INDRE
# 824    21 RUE SAINT HILAIRE    95310      ST OUEN L AUMONE
# 825        36 RUE PONSARDIN    51100                 REIMS
#
# [826 rows x 8 columns]

# %%
# tel et fax OK


# adresse du fournisseur OK

ListTel = []
ListFax = []



for i in range(len(ListUrlEntreprise)):
    
    #print(i)
    #r=requests.get(ListUrlEntreprise[i])
    #soup = BeautifulSoup(r)
    #print(soup.prettify())
    
    url=ListUrlEntreprise[i]
    source = urllib.request.urlopen(url).read()
    soup = bs4.BeautifulSoup(source)

    
    try : 
        tel=soup.find('div', class_="field field-name-field-phone field-type-text field-label-inline clearfix").find('div', class_="field-item even").text
        #print(tel)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        tel=("NR")
        #print(tel)
    ListTel.append(tel)

    try : 
        fax=soup.find('div', class_="field field-name-field-fax field-type-text field-label-inline clearfix").find('div', class_="field-item even").text
        #print(fax)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        fax=("NR")
        #print(fax)
    ListFax.append(fax)
    


df["Telephone"] = ListTel
df["Fax"] = ListFax

#print(len(df))
df
# Out:
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation  \
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
#                                         ActiviteResume  \
# 0                                                   NR
# 1    L'Entreprise Adaptée ETAPES fabrique principal...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821  LMDES une entreprise pas ordinaire pour des éq...
# 822                                                 NR
# 823  Association créée en Janvier 2012 dont l'activ...
# 824                                                 NR
# 825                                                 NR
#
#                                        ActiviteDetails  \
# 0    Transport, logistique, conditionnementLogistiq...
# 1    Nettoyage et Hygiène des locauxNettoyage et Hy...
# 2    MenuiserieBoisGestion de scierieMenuiseriefabr...
# 3    Agriculture, environnement, Espaces VertsEntre...
# 4    Agriculture, environnement, Espaces VertsEntre...
# ..                                                 ...
# 821  Gestion, administration, informatiqueTravaux a...
# 822  Impression, communication, évènementielImpress...
# 823  BlanchisserieBlanchisserie IndustrielleLinge P...
# 824  collecte, traitement et recyclage des déchetsc...
# 825  Impression, communication, évènementielAudiovi...
#
#                    Adresse1 Adresse2              Adresse3   Telephone  \
# 0             ZI DE L'OMOIS    02400       CHATEAU THIERRY  0323849307
# 1    9 RUE HENRI JEANRENAUD    39100                  DOLE  0384794479
# 2          RUE DE PONTORSON    50240              ST JAMES  0233892830
# 3         130 ZI SAINT RENE    59287              GUESNAIN  0327929797
# 4                  CHAUMONT    43360           VERGONGHEON  0471769900
# ..                      ...      ...                   ...         ...
# 821  1 IMPASSE DES PLANCHES    26190     ST JEAN EN ROYANS  0475483773
# 822         1 RUE BELLATRIX    53470  MARTIGNE SUR MAYENNE  0240837900
# 823     1 AVENUE D AUVERGNE    36160  STE SEVERE SUR INDRE  0254306684
# 824    21 RUE SAINT HILAIRE    95310      ST OUEN L AUMONE  0130304021
# 825        36 RUE PONSARDIN    51100                 REIMS  0326850617
#
#             Fax
# 0            NR
# 1    0384794474
# 2    0233898295
# 3    0327918441
# 4    0471769728
# ..          ...
# 821  0475473086
# 822  0141733259
# 823  0254306987
# 824  0130371827
# 825          NR
#
# [826 rows x 10 columns]

# %%
# email OK


ListEmail = []


for i in range(len(ListUrlEntreprise)):
    
    #print(i)
    #r=requests.get(ListUrlEntreprise[i])
    #soup = BeautifulSoup(r)
    #print(soup.prettify())
    
    url=ListUrlEntreprise[i]
    source = urllib.request.urlopen(url).read()
    soup = bs4.BeautifulSoup(source)

    
    try : 
        email=soup.find('div', class_="link-contact").find('a').text
        #print(email)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        email=("NR")
        #print(email)
    ListEmail.append(email)


df["Email"] = ListEmail

#print(len(df))
df
# Out:
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation  \
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
#                                         ActiviteResume  \
# 0                                                   NR
# 1    L'Entreprise Adaptée ETAPES fabrique principal...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821  LMDES une entreprise pas ordinaire pour des éq...
# 822                                                 NR
# 823  Association créée en Janvier 2012 dont l'activ...
# 824                                                 NR
# 825                                                 NR
#
#                                        ActiviteDetails  \
# 0    Transport, logistique, conditionnementLogistiq...
# 1    Nettoyage et Hygiène des locauxNettoyage et Hy...
# 2    MenuiserieBoisGestion de scierieMenuiseriefabr...
# 3    Agriculture, environnement, Espaces VertsEntre...
# 4    Agriculture, environnement, Espaces VertsEntre...
# ..                                                 ...
# 821  Gestion, administration, informatiqueTravaux a...
# 822  Impression, communication, évènementielImpress...
# 823  BlanchisserieBlanchisserie IndustrielleLinge P...
# 824  collecte, traitement et recyclage des déchetsc...
# 825  Impression, communication, évènementielAudiovi...
#
#                    Adresse1 Adresse2              Adresse3   Telephone  \
# 0             ZI DE L'OMOIS    02400       CHATEAU THIERRY  0323849307
# 1    9 RUE HENRI JEANRENAUD    39100                  DOLE  0384794479
# 2          RUE DE PONTORSON    50240              ST JAMES  0233892830
# 3         130 ZI SAINT RENE    59287              GUESNAIN  0327929797
# 4                  CHAUMONT    43360           VERGONGHEON  0471769900
# ..                      ...      ...                   ...         ...
# 821  1 IMPASSE DES PLANCHES    26190     ST JEAN EN ROYANS  0475483773
# 822         1 RUE BELLATRIX    53470  MARTIGNE SUR MAYENNE  0240837900
# 823     1 AVENUE D AUVERGNE    36160  STE SEVERE SUR INDRE  0254306684
# 824    21 RUE SAINT HILAIRE    95310      ST OUEN L AUMONE  0130304021
# 825        36 RUE PONSARDIN    51100                 REIMS  0326850617
#
#             Fax                       Email
# 0            NR   sbuecheler@fmlogistic.com
# 1    0384794474      etpsynergie@etapes.org
# 2    0233898295  sblocklet@etpsaintjames.fr
# 3    0327918441            contact@ethap.fr
# 4    0471769728   catherine.jarry@auvena.fr
# ..          ...                         ...
# 821  0475473086              lmdes@lmdes.fr
# 822  0141733259      jbore@groupvalpaco.com
# 823  0254306987       lbs36compta@gmail.com
# 824  0130371827        info-service@loxy.fr
# 825          NR                          NR
#
# [826 rows x 11 columns]

# %%
# adresse web OK


ListWeb = []



for i in range(len(ListUrlEntreprise)):
    
    #print(i)
    #r=requests.get(ListUrlEntreprise[i])
    #soup = BeautifulSoup(r)
    #print(soup.prettify())
    
    url=ListUrlEntreprise[i]
    source = urllib.request.urlopen(url).read()
    soup = bs4.BeautifulSoup(source)

    
    try : 
        web=soup.find('div', class_="field field-name-field-website field-type-link-field field-label-hidden").text
        web = re.sub('\n', '', web)
        #print(web)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        web=("NR")
        print(web)
    ListWeb.append(web)


df["Web"] = ListWeb

#print(len(df))
df
# Out:
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
# NR
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation  \
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
#                                         ActiviteResume  \
# 0                                                   NR
# 1    L'Entreprise Adaptée ETAPES fabrique principal...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821  LMDES une entreprise pas ordinaire pour des éq...
# 822                                                 NR
# 823  Association créée en Janvier 2012 dont l'activ...
# 824                                                 NR
# 825                                                 NR
#
#                                        ActiviteDetails  \
# 0    Transport, logistique, conditionnementLogistiq...
# 1    Nettoyage et Hygiène des locauxNettoyage et Hy...
# 2    MenuiserieBoisGestion de scierieMenuiseriefabr...
# 3    Agriculture, environnement, Espaces VertsEntre...
# 4    Agriculture, environnement, Espaces VertsEntre...
# ..                                                 ...
# 821  Gestion, administration, informatiqueTravaux a...
# 822  Impression, communication, évènementielImpress...
# 823  BlanchisserieBlanchisserie IndustrielleLinge P...
# 824  collecte, traitement et recyclage des déchetsc...
# 825  Impression, communication, évènementielAudiovi...
#
#                    Adresse1 Adresse2              Adresse3   Telephone  \
# 0             ZI DE L'OMOIS    02400       CHATEAU THIERRY  0323849307
# 1    9 RUE HENRI JEANRENAUD    39100                  DOLE  0384794479
# 2          RUE DE PONTORSON    50240              ST JAMES  0233892830
# 3         130 ZI SAINT RENE    59287              GUESNAIN  0327929797
# 4                  CHAUMONT    43360           VERGONGHEON  0471769900
# ..                      ...      ...                   ...         ...
# 821  1 IMPASSE DES PLANCHES    26190     ST JEAN EN ROYANS  0475483773
# 822         1 RUE BELLATRIX    53470  MARTIGNE SUR MAYENNE  0240837900
# 823     1 AVENUE D AUVERGNE    36160  STE SEVERE SUR INDRE  0254306684
# 824    21 RUE SAINT HILAIRE    95310      ST OUEN L AUMONE  0130304021
# 825        36 RUE PONSARDIN    51100                 REIMS  0326850617
#
#             Fax                       Email  \
# 0            NR   sbuecheler@fmlogistic.com
# 1    0384794474      etpsynergie@etapes.org
# 2    0233898295  sblocklet@etpsaintjames.fr
# 3    0327918441            contact@ethap.fr
# 4    0471769728   catherine.jarry@auvena.fr
# ..          ...                         ...
# 821  0475473086              lmdes@lmdes.fr
# 822  0141733259      jbore@groupvalpaco.com
# 823  0254306987       lbs36compta@gmail.com
# 824  0130371827        info-service@loxy.fr
# 825          NR                          NR
#
#                                          Web
# 0                   http://www.fmlogistic.fr
# 1                       http://www.etapes.fr
# 2             http://www.etp-saint-james.fr/
# 3                        http://www.ethap.fr
# 4                       http://www.auvena.fr
# ..                                       ...
# 821                     http://www.lmdes.com
# 822      http://www.imprimerie-solidaire.com
# 823  http://www.blanchisseriesseveroises.fr/
# 824                       http://www.loxy.fr
# 825                                       NR
#
# [826 rows x 12 columns]

# %%
df
# Out:
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation  \
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
#                                         ActiviteResume  \
# 0                                                   NR
# 1    L'Entreprise Adaptée ETAPES fabrique principal...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821  LMDES une entreprise pas ordinaire pour des éq...
# 822                                                 NR
# 823  Association créée en Janvier 2012 dont l'activ...
# 824                                                 NR
# 825                                                 NR
#
#                                        ActiviteDetails  \
# 0    Transport, logistique, conditionnementLogistiq...
# 1    Nettoyage et Hygiène des locauxNettoyage et Hy...
# 2    MenuiserieBoisGestion de scierieMenuiseriefabr...
# 3    Agriculture, environnement, Espaces VertsEntre...
# 4    Agriculture, environnement, Espaces VertsEntre...
# ..                                                 ...
# 821  Gestion, administration, informatiqueTravaux a...
# 822  Impression, communication, évènementielImpress...
# 823  BlanchisserieBlanchisserie IndustrielleLinge P...
# 824  collecte, traitement et recyclage des déchetsc...
# 825  Impression, communication, évènementielAudiovi...
#
#                    Adresse1 Adresse2              Adresse3   Telephone  \
# 0             ZI DE L'OMOIS    02400       CHATEAU THIERRY  0323849307
# 1    9 RUE HENRI JEANRENAUD    39100                  DOLE  0384794479
# 2          RUE DE PONTORSON    50240              ST JAMES  0233892830
# 3         130 ZI SAINT RENE    59287              GUESNAIN  0327929797
# 4                  CHAUMONT    43360           VERGONGHEON  0471769900
# ..                      ...      ...                   ...         ...
# 821  1 IMPASSE DES PLANCHES    26190     ST JEAN EN ROYANS  0475483773
# 822         1 RUE BELLATRIX    53470  MARTIGNE SUR MAYENNE  0240837900
# 823     1 AVENUE D AUVERGNE    36160  STE SEVERE SUR INDRE  0254306684
# 824    21 RUE SAINT HILAIRE    95310      ST OUEN L AUMONE  0130304021
# 825        36 RUE PONSARDIN    51100                 REIMS  0326850617
#
#             Fax                       Email  \
# 0            NR   sbuecheler@fmlogistic.com
# 1    0384794474      etpsynergie@etapes.org
# 2    0233898295  sblocklet@etpsaintjames.fr
# 3    0327918441            contact@ethap.fr
# 4    0471769728   catherine.jarry@auvena.fr
# ..          ...                         ...
# 821  0475473086              lmdes@lmdes.fr
# 822  0141733259      jbore@groupvalpaco.com
# 823  0254306987       lbs36compta@gmail.com
# 824  0130371827        info-service@loxy.fr
# 825          NR                          NR
#
#                                          Web
# 0                   http://www.fmlogistic.fr
# 1                       http://www.etapes.fr
# 2             http://www.etp-saint-james.fr/
# 3                        http://www.ethap.fr
# 4                       http://www.auvena.fr
# ..                                       ...
# 821                     http://www.lmdes.com
# 822      http://www.imprimerie-solidaire.com
# 823  http://www.blanchisseriesseveroises.fr/
# 824                       http://www.loxy.fr
# 825                                       NR
#
# [826 rows x 12 columns]

# %%
# nbre salariés OK

   
    
ListSalaries = []



for i in range(len(ListUrlEntreprise)):
    
    #print(i)
    #r=requests.get(ListUrlEntreprise[i])
    #soup = BeautifulSoup(r)
    #print(soup.prettify())
    
    url=ListUrlEntreprise[i]
    source = urllib.request.urlopen(url).read()
    soup = bs4.BeautifulSoup(source)

    
    try : 
        rh =soup.find('div', class_="field field-name-field-workforce field-type-number-integer field-label-hidden").text
        rh = re.sub('\n', '', rh)
        #print(rh)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        rh=("NR")
        #print(rh)
    ListSalaries.append(rh)


df["NbSalaries"] = ListSalaries

#print(len(df))
df
# Out:
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation  \
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
#                                         ActiviteResume  \
# 0                                                   NR
# 1    L'Entreprise Adaptée ETAPES fabrique principal...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821  LMDES une entreprise pas ordinaire pour des éq...
# 822                                                 NR
# 823  Association créée en Janvier 2012 dont l'activ...
# 824                                                 NR
# 825                                                 NR
#
#                                        ActiviteDetails  \
# 0    Transport, logistique, conditionnementLogistiq...
# 1    Nettoyage et Hygiène des locauxNettoyage et Hy...
# 2    MenuiserieBoisGestion de scierieMenuiseriefabr...
# 3    Agriculture, environnement, Espaces VertsEntre...
# 4    Agriculture, environnement, Espaces VertsEntre...
# ..                                                 ...
# 821  Gestion, administration, informatiqueTravaux a...
# 822  Impression, communication, évènementielImpress...
# 823  BlanchisserieBlanchisserie IndustrielleLinge P...
# 824  collecte, traitement et recyclage des déchetsc...
# 825  Impression, communication, évènementielAudiovi...
#
#                    Adresse1 Adresse2              Adresse3   Telephone  \
# 0             ZI DE L'OMOIS    02400       CHATEAU THIERRY  0323849307
# 1    9 RUE HENRI JEANRENAUD    39100                  DOLE  0384794479
# 2          RUE DE PONTORSON    50240              ST JAMES  0233892830
# 3         130 ZI SAINT RENE    59287              GUESNAIN  0327929797
# 4                  CHAUMONT    43360           VERGONGHEON  0471769900
# ..                      ...      ...                   ...         ...
# 821  1 IMPASSE DES PLANCHES    26190     ST JEAN EN ROYANS  0475483773
# 822         1 RUE BELLATRIX    53470  MARTIGNE SUR MAYENNE  0240837900
# 823     1 AVENUE D AUVERGNE    36160  STE SEVERE SUR INDRE  0254306684
# 824    21 RUE SAINT HILAIRE    95310      ST OUEN L AUMONE  0130304021
# 825        36 RUE PONSARDIN    51100                 REIMS  0326850617
#
#             Fax                       Email  \
# 0            NR   sbuecheler@fmlogistic.com
# 1    0384794474      etpsynergie@etapes.org
# 2    0233898295  sblocklet@etpsaintjames.fr
# 3    0327918441            contact@ethap.fr
# 4    0471769728   catherine.jarry@auvena.fr
# ..          ...                         ...
# 821  0475473086              lmdes@lmdes.fr
# 822  0141733259      jbore@groupvalpaco.com
# 823  0254306987       lbs36compta@gmail.com
# 824  0130371827        info-service@loxy.fr
# 825          NR                          NR
#
#                                          Web NbSalaries
# 0                   http://www.fmlogistic.fr         23
# 1                       http://www.etapes.fr         42
# 2             http://www.etp-saint-james.fr/         92
# 3                        http://www.ethap.fr         44
# 4                       http://www.auvena.fr        178
# ..                                       ...        ...
# 821                     http://www.lmdes.com         57
# 822      http://www.imprimerie-solidaire.com         60
# 823  http://www.blanchisseriesseveroises.fr/         NR
# 824                       http://www.loxy.fr         NR
# 825                                       NR         NR
#
# [826 rows x 13 columns]

# %%
# num siret OK



ListSiret = []


for i in range(len(ListUrlEntreprise)):
    
    #print(i)
    #r=requests.get(ListUrlEntreprise[i])
    #soup = BeautifulSoup(r)
    #print(soup.prettify())
    
    url=ListUrlEntreprise[i]
    source = urllib.request.urlopen(url).read()
    soup = bs4.BeautifulSoup(source)

    
    try : 
        siret=soup.find('div', class_="field field-name-field-siret field-type-text field-label-above").find('div', class_="field-item even").text
        #print(siret)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        siret=("NR")
        #print(siret)
    ListSiret.append(siret)


df["SIRET"] = ListSiret

#print(len(df))
df
# Out:
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation  \
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
#                                         ActiviteResume  \
# 0                                                   NR
# 1    L'Entreprise Adaptée ETAPES fabrique principal...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821  LMDES une entreprise pas ordinaire pour des éq...
# 822                                                 NR
# 823  Association créée en Janvier 2012 dont l'activ...
# 824                                                 NR
# 825                                                 NR
#
#                                        ActiviteDetails  \
# 0    Transport, logistique, conditionnementLogistiq...
# 1    Nettoyage et Hygiène des locauxNettoyage et Hy...
# 2    MenuiserieBoisGestion de scierieMenuiseriefabr...
# 3    Agriculture, environnement, Espaces VertsEntre...
# 4    Agriculture, environnement, Espaces VertsEntre...
# ..                                                 ...
# 821  Gestion, administration, informatiqueTravaux a...
# 822  Impression, communication, évènementielImpress...
# 823  BlanchisserieBlanchisserie IndustrielleLinge P...
# 824  collecte, traitement et recyclage des déchetsc...
# 825  Impression, communication, évènementielAudiovi...
#
#                    Adresse1 Adresse2              Adresse3   Telephone  \
# 0             ZI DE L'OMOIS    02400       CHATEAU THIERRY  0323849307
# 1    9 RUE HENRI JEANRENAUD    39100                  DOLE  0384794479
# 2          RUE DE PONTORSON    50240              ST JAMES  0233892830
# 3         130 ZI SAINT RENE    59287              GUESNAIN  0327929797
# 4                  CHAUMONT    43360           VERGONGHEON  0471769900
# ..                      ...      ...                   ...         ...
# 821  1 IMPASSE DES PLANCHES    26190     ST JEAN EN ROYANS  0475483773
# 822         1 RUE BELLATRIX    53470  MARTIGNE SUR MAYENNE  0240837900
# 823     1 AVENUE D AUVERGNE    36160  STE SEVERE SUR INDRE  0254306684
# 824    21 RUE SAINT HILAIRE    95310      ST OUEN L AUMONE  0130304021
# 825        36 RUE PONSARDIN    51100                 REIMS  0326850617
#
#             Fax                       Email  \
# 0            NR   sbuecheler@fmlogistic.com
# 1    0384794474      etpsynergie@etapes.org
# 2    0233898295  sblocklet@etpsaintjames.fr
# 3    0327918441            contact@ethap.fr
# 4    0471769728   catherine.jarry@auvena.fr
# ..          ...                         ...
# 821  0475473086              lmdes@lmdes.fr
# 822  0141733259      jbore@groupvalpaco.com
# 823  0254306987       lbs36compta@gmail.com
# 824  0130371827        info-service@loxy.fr
# 825          NR                          NR
#
#                                          Web NbSalaries           SIRET
# 0                   http://www.fmlogistic.fr         23  82522225000011
# 1                       http://www.etapes.fr         42  26390024300282
# 2             http://www.etp-saint-james.fr/         92  26500145300017
# 3                        http://www.ethap.fr         44  34894705200042
# 4                       http://www.auvena.fr        178  50753926000012
# ..                                       ...        ...             ...
# 821                     http://www.lmdes.com         57  44894491800037
# 822      http://www.imprimerie-solidaire.com         60  79484911700013
# 823  http://www.blanchisseriesseveroises.fr/         NR  75063261400012
# 824                       http://www.loxy.fr         NR  48264495200046
# 825                                       NR         NR  82528461500010
#
# [826 rows x 14 columns]

# %%
# certification OK

ListCertifications = []


for i in range(len(ListUrlEntreprise)):
    
    #print(i)
    #r=requests.get(ListUrlEntreprise[i])
    #soup = BeautifulSoup(r)
    #print(soup.prettify())
    
    url=ListUrlEntreprise[i]
    source = urllib.request.urlopen(url).read()
    soup = bs4.BeautifulSoup(source)

    
    try : 
        certificat=soup.find('div', class_="field field-name-field-certifications field-type-text-long field-label-above").find('div', class_="field-item even").text
        #print(certificat)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        certificat=("NR")
        #print(certificat)
    ListCertifications.append(certificat)


df["Certifications"] = ListCertifications

#print(len(df))
df
# Out:
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation  \
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
#                                         ActiviteResume  \
# 0                                                   NR
# 1    L'Entreprise Adaptée ETAPES fabrique principal...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821  LMDES une entreprise pas ordinaire pour des éq...
# 822                                                 NR
# 823  Association créée en Janvier 2012 dont l'activ...
# 824                                                 NR
# 825                                                 NR
#
#                                        ActiviteDetails  \
# 0    Transport, logistique, conditionnementLogistiq...
# 1    Nettoyage et Hygiène des locauxNettoyage et Hy...
# 2    MenuiserieBoisGestion de scierieMenuiseriefabr...
# 3    Agriculture, environnement, Espaces VertsEntre...
# 4    Agriculture, environnement, Espaces VertsEntre...
# ..                                                 ...
# 821  Gestion, administration, informatiqueTravaux a...
# 822  Impression, communication, évènementielImpress...
# 823  BlanchisserieBlanchisserie IndustrielleLinge P...
# 824  collecte, traitement et recyclage des déchetsc...
# 825  Impression, communication, évènementielAudiovi...
#
#                    Adresse1 Adresse2              Adresse3   Telephone  \
# 0             ZI DE L'OMOIS    02400       CHATEAU THIERRY  0323849307
# 1    9 RUE HENRI JEANRENAUD    39100                  DOLE  0384794479
# 2          RUE DE PONTORSON    50240              ST JAMES  0233892830
# 3         130 ZI SAINT RENE    59287              GUESNAIN  0327929797
# 4                  CHAUMONT    43360           VERGONGHEON  0471769900
# ..                      ...      ...                   ...         ...
# 821  1 IMPASSE DES PLANCHES    26190     ST JEAN EN ROYANS  0475483773
# 822         1 RUE BELLATRIX    53470  MARTIGNE SUR MAYENNE  0240837900
# 823     1 AVENUE D AUVERGNE    36160  STE SEVERE SUR INDRE  0254306684
# 824    21 RUE SAINT HILAIRE    95310      ST OUEN L AUMONE  0130304021
# 825        36 RUE PONSARDIN    51100                 REIMS  0326850617
#
#             Fax                       Email  \
# 0            NR   sbuecheler@fmlogistic.com
# 1    0384794474      etpsynergie@etapes.org
# 2    0233898295  sblocklet@etpsaintjames.fr
# 3    0327918441            contact@ethap.fr
# 4    0471769728   catherine.jarry@auvena.fr
# ..          ...                         ...
# 821  0475473086              lmdes@lmdes.fr
# 822  0141733259      jbore@groupvalpaco.com
# 823  0254306987       lbs36compta@gmail.com
# 824  0130371827        info-service@loxy.fr
# 825          NR                          NR
#
#                                          Web NbSalaries           SIRET  \
# 0                   http://www.fmlogistic.fr         23  82522225000011
# 1                       http://www.etapes.fr         42  26390024300282
# 2             http://www.etp-saint-james.fr/         92  26500145300017
# 3                        http://www.ethap.fr         44  34894705200042
# 4                       http://www.auvena.fr        178  50753926000012
# ..                                       ...        ...             ...
# 821                     http://www.lmdes.com         57  44894491800037
# 822      http://www.imprimerie-solidaire.com         60  79484911700013
# 823  http://www.blanchisseriesseveroises.fr/         NR  75063261400012
# 824                       http://www.loxy.fr         NR  48264495200046
# 825                                       NR         NR  82528461500010
#
#           Certifications
# 0                     NR
# 1     NF ISO 9001 : 2000
# 2                     NR
# 3                   PEFC
# 4             VALEO 1000
# ..                   ...
# 821                   NR
# 822                   NR
# 823                   NR
# 824  en cours d'ISO 9001
# 825                   NR
#
# [826 rows x 15 columns]

# %%
# contact OK

ListContactNom = []
ListContactPrenom = []
ListContactFct = []
ListContactTel = []

for i in range(len(ListUrlEntreprise)):
    
    #print(i)
    #r=requests.get(ListUrlEntreprise[i])
    #soup = BeautifulSoup(r)
    #print(soup.prettify())
    
    url=ListUrlEntreprise[i]
    source = urllib.request.urlopen(url).read()
    soup = bs4.BeautifulSoup(source)

    
    try : 
        contact_prenom=soup.find('div', class_="field field-name-field-leader-firstname field-type-text field-label-hidden").find('div', class_="field-item even").text
        #print(contact_prenom)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        contact_prenom=("NR")
        #print(contact_prenom)
    ListContactPrenom.append(contact_prenom)

    try : 
        contact_nom=soup.find('div', class_="field field-name-field-leader-name field-type-text field-label-hidden").find('div', class_="field-item even").text
        #print(contact_nom)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        contact_nom=("NR")
        #print(contact_nom)
    ListContactNom.append(contact_nom)

    try : 
        contact_fct=soup.find('div', class_="field field-name-field-leader-capacity field-type-text field-label-hidden").find('div', class_="field-item even").text
        #print(contact_fct)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        contact_fct=("NR")
        #print(contact_fct)
    ListContactFct.append(contact_fct)
    
    try : 
        contact_tel=soup.find('div', class_="field field-name-field-leader-phone field-type-text field-label-inline clearfix").find('div', class_="field-item even").text
        #print(contact_tel)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        contact_tel=("NR")
        #print(contact_tel)
    ListContactTel.append(contact_tel)
        


df["Contact_Prenom"] = ListContactPrenom
df["Contact_Nom"] = ListContactNom
df["Contact_Fonction"] = ListContactFct
df["Contact_Tel"] = ListContactTel

#print(len(df))
df
# Out:
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation  \
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
#                                         ActiviteResume  \
# 0                                                   NR
# 1    L'Entreprise Adaptée ETAPES fabrique principal...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821  LMDES une entreprise pas ordinaire pour des éq...
# 822                                                 NR
# 823  Association créée en Janvier 2012 dont l'activ...
# 824                                                 NR
# 825                                                 NR
#
#                                        ActiviteDetails  \
# 0    Transport, logistique, conditionnementLogistiq...
# 1    Nettoyage et Hygiène des locauxNettoyage et Hy...
# 2    MenuiserieBoisGestion de scierieMenuiseriefabr...
# 3    Agriculture, environnement, Espaces VertsEntre...
# 4    Agriculture, environnement, Espaces VertsEntre...
# ..                                                 ...
# 821  Gestion, administration, informatiqueTravaux a...
# 822  Impression, communication, évènementielImpress...
# 823  BlanchisserieBlanchisserie IndustrielleLinge P...
# 824  collecte, traitement et recyclage des déchetsc...
# 825  Impression, communication, évènementielAudiovi...
#
#                    Adresse1 Adresse2              Adresse3   Telephone  \
# 0             ZI DE L'OMOIS    02400       CHATEAU THIERRY  0323849307
# 1    9 RUE HENRI JEANRENAUD    39100                  DOLE  0384794479
# 2          RUE DE PONTORSON    50240              ST JAMES  0233892830
# 3         130 ZI SAINT RENE    59287              GUESNAIN  0327929797
# 4                  CHAUMONT    43360           VERGONGHEON  0471769900
# ..                      ...      ...                   ...         ...
# 821  1 IMPASSE DES PLANCHES    26190     ST JEAN EN ROYANS  0475483773
# 822         1 RUE BELLATRIX    53470  MARTIGNE SUR MAYENNE  0240837900
# 823     1 AVENUE D AUVERGNE    36160  STE SEVERE SUR INDRE  0254306684
# 824    21 RUE SAINT HILAIRE    95310      ST OUEN L AUMONE  0130304021
# 825        36 RUE PONSARDIN    51100                 REIMS  0326850617
#
#             Fax                       Email  \
# 0            NR   sbuecheler@fmlogistic.com
# 1    0384794474      etpsynergie@etapes.org
# 2    0233898295  sblocklet@etpsaintjames.fr
# 3    0327918441            contact@ethap.fr
# 4    0471769728   catherine.jarry@auvena.fr
# ..          ...                         ...
# 821  0475473086              lmdes@lmdes.fr
# 822  0141733259      jbore@groupvalpaco.com
# 823  0254306987       lbs36compta@gmail.com
# 824  0130371827        info-service@loxy.fr
# 825          NR                          NR
#
#                                          Web NbSalaries           SIRET  \
# 0                   http://www.fmlogistic.fr         23  82522225000011
# 1                       http://www.etapes.fr         42  26390024300282
# 2             http://www.etp-saint-james.fr/         92  26500145300017
# 3                        http://www.ethap.fr         44  34894705200042
# 4                       http://www.auvena.fr        178  50753926000012
# ..                                       ...        ...             ...
# 821                     http://www.lmdes.com         57  44894491800037
# 822      http://www.imprimerie-solidaire.com         60  79484911700013
# 823  http://www.blanchisseriesseveroises.fr/         NR  75063261400012
# 824                       http://www.loxy.fr         NR  48264495200046
# 825                                       NR         NR  82528461500010
#
#           Certifications Contact_Prenom Contact_Nom  \
# 0                     NR       SANDRINE   BUECHELER
# 1     NF ISO 9001 : 2000         Gilles  Grosperrin
# 2                     NR       Aurélien       LEMEE
# 3                   PEFC           Joël      ARCHIE
# 4             VALEO 1000      Catherine       JARRY
# ..                   ...            ...         ...
# 821                   NR             NR          NR
# 822                   NR             NR          NR
# 823                   NR             NR          NR
# 824  en cours d'ISO 9001             NR          NR
# 825                   NR             NR          NR
#
#               Contact_Fonction Contact_Tel
# 0                      Gérante          NR
# 1    Directeur d'établissement  0384794478
# 2            Directeur adjoint          NR
# 3                    Directeur  0327929788
# 4                   Directrice  0471769900
# ..                         ...         ...
# 821                         NR          NR
# 822                         NR          NR
# 823                         NR          NR
# 824                         NR          NR
# 825                         NR          NR
#
# [826 rows x 19 columns]

# %%
# clients principaux OK

    
    
ListClients = []


for i in range(len(ListUrlEntreprise)):
    
    #print(i)
    #r=requests.get(ListUrlEntreprise[i])
    #soup = BeautifulSoup(r)
    #print(soup.prettify())
    
    url=ListUrlEntreprise[i]
    source = urllib.request.urlopen(url).read()
    soup = bs4.BeautifulSoup(source)

    
    try : 
        clients=soup.find('div', class_="field field-name-field-main-customers field-type-text-long field-label-hidden").find('div', class_="field-item even").text
        clients = re.sub('\n', '', clients)
        #print(clients)
    except (RuntimeError, TypeError, NameError, SyntaxError, AttributeError) :
        clients=("NR")
        #print(clients)
    ListClients.append(clients)


df["Clients"] = ListClients

#print(len(df))
df
# Out:
#                         Entreprise  \
# 0             FMEA HAUTS DE FRANCE
# 1                     ETP SYNERGIE
# 2                     ETP ST JAMES
# 3                        ETHAP NPC
# 4                ETAPE AUVERGNE 43
# ..                             ...
# 821                          LMDES
# 822         L'IMPRIMERIE SOLIDAIRE
# 823  LES BLANCHISSERIES SEVEROISES
# 824        ENTREPRISE ADAPTEE LOXY
# 825               LEA DE CHAMPAGNE
#
#                                                    URL  \
# 0    https://www.unea.fr/fmea-hauts-de-france?secto...
# 1    https://www.unea.fr/etp-synergie?sector=0&sect...
# 2    https://www.unea.fr/etp-st-james?sector=0&sect...
# 3    https://www.unea.fr/ethap-npc?sector=0&section...
# 4    https://www.unea.fr/etape-auvergne-43?sector=0...
# ..                                                 ...
# 821  https://www.unea.fr/lmdes?sector=0&section=0&a...
# 822  https://www.unea.fr/limprimerie-solidaire?sect...
# 823  https://www.unea.fr/les-blanchisseries-severoi...
# 824  https://www.unea.fr/entreprise-adaptee-loxy?se...
# 825  https://www.unea.fr/lea-de-champagne?sector=0&...
#
#                    Localisation  \
# 0         02400 CHATEAU THIERRY
# 1                    39100 DOLE
# 2                50240 ST JAMES
# 3                59287 GUESNAIN
# 4             43360 VERGONGHEON
# ..                          ...
# 821     26190 ST JEAN EN ROYANS
# 822  53470 MARTIGNE SUR MAYENNE
# 823  36160 STE SEVERE SUR INDRE
# 824      95310 ST OUEN L AUMONE
# 825                 51100 REIMS
#
#                                         ActiviteResume  \
# 0                                                   NR
# 1    L'Entreprise Adaptée ETAPES fabrique principal...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821  LMDES une entreprise pas ordinaire pour des éq...
# 822                                                 NR
# 823  Association créée en Janvier 2012 dont l'activ...
# 824                                                 NR
# 825                                                 NR
#
#                                        ActiviteDetails  \
# 0    Transport, logistique, conditionnementLogistiq...
# 1    Nettoyage et Hygiène des locauxNettoyage et Hy...
# 2    MenuiserieBoisGestion de scierieMenuiseriefabr...
# 3    Agriculture, environnement, Espaces VertsEntre...
# 4    Agriculture, environnement, Espaces VertsEntre...
# ..                                                 ...
# 821  Gestion, administration, informatiqueTravaux a...
# 822  Impression, communication, évènementielImpress...
# 823  BlanchisserieBlanchisserie IndustrielleLinge P...
# 824  collecte, traitement et recyclage des déchetsc...
# 825  Impression, communication, évènementielAudiovi...
#
#                    Adresse1 Adresse2              Adresse3   Telephone  \
# 0             ZI DE L'OMOIS    02400       CHATEAU THIERRY  0323849307
# 1    9 RUE HENRI JEANRENAUD    39100                  DOLE  0384794479
# 2          RUE DE PONTORSON    50240              ST JAMES  0233892830
# 3         130 ZI SAINT RENE    59287              GUESNAIN  0327929797
# 4                  CHAUMONT    43360           VERGONGHEON  0471769900
# ..                      ...      ...                   ...         ...
# 821  1 IMPASSE DES PLANCHES    26190     ST JEAN EN ROYANS  0475483773
# 822         1 RUE BELLATRIX    53470  MARTIGNE SUR MAYENNE  0240837900
# 823     1 AVENUE D AUVERGNE    36160  STE SEVERE SUR INDRE  0254306684
# 824    21 RUE SAINT HILAIRE    95310      ST OUEN L AUMONE  0130304021
# 825        36 RUE PONSARDIN    51100                 REIMS  0326850617
#
#             Fax                       Email  \
# 0            NR   sbuecheler@fmlogistic.com
# 1    0384794474      etpsynergie@etapes.org
# 2    0233898295  sblocklet@etpsaintjames.fr
# 3    0327918441            contact@ethap.fr
# 4    0471769728   catherine.jarry@auvena.fr
# ..          ...                         ...
# 821  0475473086              lmdes@lmdes.fr
# 822  0141733259      jbore@groupvalpaco.com
# 823  0254306987       lbs36compta@gmail.com
# 824  0130371827        info-service@loxy.fr
# 825          NR                          NR
#
#                                          Web NbSalaries           SIRET  \
# 0                   http://www.fmlogistic.fr         23  82522225000011
# 1                       http://www.etapes.fr         42  26390024300282
# 2             http://www.etp-saint-james.fr/         92  26500145300017
# 3                        http://www.ethap.fr         44  34894705200042
# 4                       http://www.auvena.fr        178  50753926000012
# ..                                       ...        ...             ...
# 821                     http://www.lmdes.com         57  44894491800037
# 822      http://www.imprimerie-solidaire.com         60  79484911700013
# 823  http://www.blanchisseriesseveroises.fr/         NR  75063261400012
# 824                       http://www.loxy.fr         NR  48264495200046
# 825                                       NR         NR  82528461500010
#
#           Certifications Contact_Prenom Contact_Nom  \
# 0                     NR       SANDRINE   BUECHELER
# 1     NF ISO 9001 : 2000         Gilles  Grosperrin
# 2                     NR       Aurélien       LEMEE
# 3                   PEFC           Joël      ARCHIE
# 4             VALEO 1000      Catherine       JARRY
# ..                   ...            ...         ...
# 821                   NR             NR          NR
# 822                   NR             NR          NR
# 823                   NR             NR          NR
# 824  en cours d'ISO 9001             NR          NR
# 825                   NR             NR          NR
#
#               Contact_Fonction Contact_Tel  \
# 0                      Gérante          NR
# 1    Directeur d'établissement  0384794478
# 2            Directeur adjoint          NR
# 3                    Directeur  0327929788
# 4                   Directrice  0471769900
# ..                         ...         ...
# 821                         NR          NR
# 822                         NR          NR
# 823                         NR          NR
# 824                         NR          NR
# 825                         NR          NR
#
#                                                Clients
# 0                                                   NR
# 1    ALSTOM - PLASTO - KOHLER - LA CITE DES SCIENCE...
# 2                                                   NR
# 3                                                   NR
# 4                                                   NR
# ..                                                 ...
# 821                          2 ponts, ERDF, MGEN, Isra
# 822                                                 NR
# 823                                                 NR
# 824                          Société et administration
# 825                                                 NR
#
# [826 rows x 20 columns]

# %%
df.to_csv (r'C:\Users\Hyboui\Desktop\export_unea.csv', index = True, header=True)

# %%
df.to_excel (r'C:\Users\Hyboui\Desktop\export_unea.xlsx', index = True, header=True)

# %%
df.iloc[125:130,:]
#df.loc[df['ActiviteResume']!="NR", :]
# Out:
#                        Entreprise  \
# 125                  EA GAUDINETO
# 126        EA FONDATION SONNENHOF
# 127        EA DU CCAS DE CLERMONT
# 128               EA RESTAUVEZERE
# 129  ENTREPRISE ADAPTEE LE VERNOY
#
#                                                    URL  \
# 125  https://www.unea.fr/ea-gaudineto?sector=0&sect...
# 126  https://www.unea.fr/ea-fondation-sonnenhof?sec...
# 127  https://www.unea.fr/ea-du-ccas-de-clermont?sec...
# 128  https://www.unea.fr/ea-restauvezere?sector=0&s...
# 129  https://www.unea.fr/entreprise-adaptee-le-vern...
#
#                        Localisation  \
# 125         13300 SALON DE PROVENCE
# 126               67240 BISCHWILLER
# 127  63013 CLERMONT FERRAND CEDEX 1
# 128         24640 STE EULALIE D ANS
# 129                 71210 ST EUSEBE
#
#                                         ActiviteResume  \
# 125                                                 NR
# 126  ImprimerieMenuiserie : transformation de panne...
# 127                                                 NR
# 128                                                 NR
# 129  Nos activités : réfection d'appartements pour ...
#
#                                        ActiviteDetails              Adresse1  \
# 125  RestaurationRestaurationrestauration collectiv...  CHEMIN DU SANS SOUCI
# 126  Agriculture, environnement, Espaces VertsEntre...   22 RUE D'OBERHOFFEN
# 127  Agriculture, environnement, Espaces VertsEntre...   1 RUE SAINT VINCENT
# 128    RestaurationRestaurationrestauration collective       ZONE ARTIZANALE
# 129  Batiment et travaux publicsSecond œuvrePeintur...           ZA DU MONAY
#
#     Adresse2                  Adresse3          Telephone         Fax  \
# 125    13300         SALON DE PROVENCE  +33 4 90 17 06 14  0490170341
# 126    67240               BISCHWILLER         0388802400  0388802410
# 127    63013  CLERMONT FERRAND CEDEX 1         0473902048  0473911577
# 128    24640         STE EULALIE D ANS         0553625532  0553625533
# 129    71210                 ST EUSEBE         0385732754  0385785840
#
#                                   Email                                 Web  \
# 125  y.moulin.poletravail@agapei13no.fr    http://eagaudineto@agapei13no.fr
# 126        esat@fondation-sonnenhof.org  http://www.fondation-sonnenhof.org
# 127        cat@ccas-clermont-ferrand.fr                                  NR
# 128      jm.cichowlas@apei-perigueux.fr                                  NR
# 129        ea.levernoy@epsmslevernoy.fr                                  NR
#
#     NbSalaries           SIRET         Certifications Contact_Prenom  \
# 125         15  77555769700072                     NR           YANN
# 126         51  77873521700037  ISO 9001\nImprim'Vert      Jean-Marc
# 127         11  26630007800125                     NR         Sylvie
# 128         18  78170365700168                     NR      Jean-Marc
# 129         30  26710676300050                     NR      JEAN-MARC
#
#         Contact_Nom             Contact_Fonction Contact_Tel  \
# 125          MOULIN    Responsable de production          NR
# 126           STAUB                    Directeur          NR
# 127  BABUT DESNOYER  Responsable d'établissement          NR
# 128       CICHOWLAS                    Directeur          NR
# 129        PIETRIGA                    Directeur  0385684275
#
#                                   Clients
# 125                                    NR
# 126                                    NR
# 127                                    NR
# 128                                    NR
# 129  OPAC, VELDEMAN, OPS, ville de Blanzy
